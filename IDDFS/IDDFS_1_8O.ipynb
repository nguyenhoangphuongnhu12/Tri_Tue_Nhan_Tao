# %% [markdown]
# 24110042 - Nguyễn Hoàng Phương Như
# IDDFS APPROACH 1
# https://github.com/nguyenhoangphuongnhu12/Tri_Tue_Nhan_Tao

# %%
#Dùng thư viện from copy import deepcopy để 
#Tạo ra một bản sao y hệt ma trận cũ
#Rồi sửa bản sao đó để thành node con.

from copy import deepcopy

# %%
#Node class: Lưu trữ cấu trúc dữ liệu Node
class Node:
    def __init__(self, state, parent = None, action = None, 
                 step = 0, depth = 0, name = 'A' ):
        self.state = state
        self.parent = parent
        self.action = action
        self.step = step
        self.depth = depth
        self.name = name
        
    #Hàm biến object thành một chuỗi văn bản (string) để đại diện cho nó
    #Vd in ra REACHED: [A, B, C]    
    def __repr__(self):
        return f"{self.nameham}"

# %%
#Ma trận 3x3
n = 3

#Hàm in ma trận
def print_state(state):
    for row in state:
        print(row)
    print()
    
#Hàm so sánh hai ma trận
def is_goal(state, goal):
    return state == goal

#Hàm tìm vị trí số 0
def find_zero(state):
    for i in range(n):
        for j in range(n):
            if state[i][j] == 0:
                return i, j

# %%
#Hàm sinh node con
def generate_children(node):
    children = []
    x, y = find_zero(node.state)

    moves = [
        ("U", -1, 0),
        ("D", 1, 0),
        ("L", 0, -1),
        ("R", 0, 1),
    ]

    #Hàm enumerate() sẽ tự động đính kèm một con số chỉ mục (index) vào trước mỗi phần tử. 
    #index từ 1 đến 4
    #vd: (1, ("U", -1, 0)) | (2, ("D", 1, 0)) ...
    for index, (action, dx, dy) in enumerate(moves, start=1):
        nx = x + dx
        ny = y + dy

        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = deepcopy(node.state)
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]

            # Tên mới ghép từ Tên_Cha và Số_Thứ_Tự_Con
            child_name = f"{node.name}{index}" 

            child = Node(
                state=new_state,
                parent=node,
                action=action,
                step=node.step + 1,
                depth=node.depth + 1,
                name=child_name,
            )
            children.append(child)

    return children

# %%
#Hàm in frontier 
def print_frontier(frontier):
    print("\nFRONTIER:")
    if not frontier:
        print("[]")
        return
    
    for node in frontier:
        print(
            f"{node.name}, "
            f"action={node.action}, "
            f"step={node.step}, "
            f"depth={node.depth}"
        )
        print_state(node.state)

# %%
#Hàm in Reached
def print_reached(reached):
    print("REACHED:", [node.name for node in reached])

# %%
#Hàm truy vết tìm lời giải
def solution_path(node):
    path = []
    
    while node:
        path.append(node)
        node = node.parent

    path.reverse()
    return path

# %%
#Hàm Depth Limit Search Approach 1 
#(pop -> check goal -> sinh node con -> bỏ vô frontier -> bỏ vô reached)

def depth_limited_search(start, goal, limit):
    frontier = [start]
    reached = []
    
    while frontier:
        #STACK -> LIFO -> pop node cuối
        current = frontier.pop()
        
        print("====================================")
        print(f"POP NODE: {current.name}")
        print_state(current.state)

        #Kiểm tra goal sau khi pop
        if is_goal(current.state, goal):
            print(f"GOAL FOUND: {current.name}")
            return current
        
        #Không phải goal -> sinh con
        if current.depth < limit:
            
            children = generate_children(current)
            
            for child in children:

                # tránh lặp state trong reached
                duplicated = False

                for r in reached:
                    if r.state == child.state:
                        duplicated = True
                        break

                if not duplicated:

                    frontier.append(child)

                    print(
                        f"ADD -> {child.name}, "
                        f"parent={current.name}, "
                        f"action={child.action}, "
                        f"step={child.step}, "
                        f"depth={child.depth}"
                    )

        print_frontier(frontier)
        
        #Thêm vào reached
        reached.append(current)

        print_reached(reached)

    return None

# %%
#Hàm IDDFS
def iddfs(start_state, goal_state, max_depth):

    start_node = Node(
        state=start_state,
        parent=None,
        action=None,
        step=0,
        depth=0,
        name="A"
    )

    for limit in range(max_depth + 1):

        print("\n\n====================================")
        print(f"IDDFS DEPTH = {limit}")

        result = depth_limited_search(
            start_node,
            goal_state,
            limit
        )

        if result:
            return result

    return None

# %%
#Hàm chính
start = [
    [1, 2, 3],
    [4, 0, 6],
    [7, 5, 8]
]

goal = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0]
]

# Chạy thuật toán
result = iddfs(start, goal, max_depth=10)
# Out:
# ====================================
# IDDFS DEPTH = 0
# ====================================
# POP NODE: A
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
#
# FRONTIER:
# []
# REACHED: ['A']
#
#
# ====================================
# IDDFS DEPTH = 1
# ====================================
# POP NODE: A
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
# ADD -> A1, parent=A, action=U, step=1, depth=1
# ADD -> A2, parent=A, action=D, step=1, depth=1
# ADD -> A3, parent=A, action=L, step=1, depth=1
# ADD -> A4, parent=A, action=R, step=1, depth=1
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A3, action=L, step=1, depth=1
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
# A4, action=R, step=1, depth=1
# [1, 2, 3]
# [4, 6, 0]
# [7, 5, 8]
#
# REACHED: ['A']
# ====================================
# POP NODE: A4
# [1, 2, 3]
# [4, 6, 0]
# [7, 5, 8]
#
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A3, action=L, step=1, depth=1
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
# REACHED: ['A', 'A4']
# ====================================
# POP NODE: A3
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# REACHED: ['A', 'A4', 'A3']
# ====================================
# POP NODE: A2
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# REACHED: ['A', 'A4', 'A3', 'A2']
# ====================================
# POP NODE: A1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
#
# FRONTIER:
# []
# REACHED: ['A', 'A4', 'A3', 'A2', 'A1']
#
#
# ====================================
# IDDFS DEPTH = 2
# ====================================
# POP NODE: A
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
# ADD -> A1, parent=A, action=U, step=1, depth=1
# ADD -> A2, parent=A, action=D, step=1, depth=1
# ADD -> A3, parent=A, action=L, step=1, depth=1
# ADD -> A4, parent=A, action=R, step=1, depth=1
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A3, action=L, step=1, depth=1
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
# A4, action=R, step=1, depth=1
# [1, 2, 3]
# [4, 6, 0]
# [7, 5, 8]
#
# REACHED: ['A']
# ====================================
# POP NODE: A4
# [1, 2, 3]
# [4, 6, 0]
# [7, 5, 8]
#
# ADD -> A41, parent=A4, action=U, step=2, depth=2
# ADD -> A42, parent=A4, action=D, step=2, depth=2
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A3, action=L, step=1, depth=1
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
# A41, action=U, step=2, depth=2
# [1, 2, 0]
# [4, 6, 3]
# [7, 5, 8]
#
# A42, action=D, step=2, depth=2
# [1, 2, 3]
# [4, 6, 8]
# [7, 5, 0]
#
# REACHED: ['A', 'A4']
# ====================================
# POP NODE: A42
# [1, 2, 3]
# [4, 6, 8]
# [7, 5, 0]
#
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A3, action=L, step=1, depth=1
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
# A41, action=U, step=2, depth=2
# [1, 2, 0]
# [4, 6, 3]
# [7, 5, 8]
#
# REACHED: ['A', 'A4', 'A42']
# ====================================
# POP NODE: A41
# [1, 2, 0]
# [4, 6, 3]
# [7, 5, 8]
#
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A3, action=L, step=1, depth=1
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
# REACHED: ['A', 'A4', 'A42', 'A41']
# ====================================
# POP NODE: A3
# [1, 2, 3]
# [0, 4, 6]
# [7, 5, 8]
#
# ADD -> A31, parent=A3, action=U, step=2, depth=2
# ADD -> A32, parent=A3, action=D, step=2, depth=2
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A31, action=U, step=2, depth=2
# [0, 2, 3]
# [1, 4, 6]
# [7, 5, 8]
#
# A32, action=D, step=2, depth=2
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
#
# REACHED: ['A', 'A4', 'A42', 'A41', 'A3']
# ====================================
# POP NODE: A32
# [1, 2, 3]
# [7, 4, 6]
# [0, 5, 8]
#
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# A31, action=U, step=2, depth=2
# [0, 2, 3]
# [1, 4, 6]
# [7, 5, 8]
#
# REACHED: ['A', 'A4', 'A42', 'A41', 'A3', 'A32']
# ====================================
# POP NODE: A31
# [0, 2, 3]
# [1, 4, 6]
# [7, 5, 8]
#
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# REACHED: ['A', 'A4', 'A42', 'A41', 'A3', 'A32', 'A31']
# ====================================
# POP NODE: A2
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# ADD -> A23, parent=A2, action=L, step=2, depth=2
# ADD -> A24, parent=A2, action=R, step=2, depth=2
#
# FRONTIER:
# A1, action=U, step=1, depth=1
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
#
# A23, action=L, step=2, depth=2
# [1, 2, 3]
# [4, 5, 6]
# [0, 7, 8]
#
# A24, action=R, step=2, depth=2
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
#
# REACHED: ['A', 'A4', 'A42', 'A41', 'A3', 'A32', 'A31', 'A2']
# ====================================
# POP NODE: A24
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
#
# GOAL FOUND: A24

# %%
#Hàm in đường đi
if result:

    print("\n==============================")
    print("SOLUTION PATH")
    print("==============================")

    path = solution_path(result)

    for node in path:
        print(
            f"Node={node.name}, "
            f"action={node.action}, "
            f"step={node.step}, "
            f"depth={node.depth}"
        )
        print_state(node.state)

else:
    print("Không tìm thấy lời giải")
# Out:
# ==============================
# SOLUTION PATH
# ==============================
# Node=A, action=None, step=0, depth=0
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
#
# Node=A2, action=D, step=1, depth=1
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
#
# Node=A24, action=R, step=2, depth=2
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]
